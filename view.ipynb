# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Load dataset

# %%
df = pd.read_csv('crop_yield_data.csv')
df
# Out:
#       rainfall_mm  soil_quality_index  farm_size_hectares  sunlight_hours  \
# 0            1626                   9                 636              11
# 1            1959                   9                  73              11
# 2            1360                   1                 352               5
# 3            1794                   2                 948               7
# 4            1630                   5                 884               5
# ...           ...                 ...                 ...             ...
# 2995         1483                   9                  78              12
# 2996          804                   9                 481               4
# 2997          870                   1                 113               7
# 2998         1352                   6                 767              11
# 2999          883                   7                 170              11
#
#       fertilizer_kg  crop_yield
# 0              1006         404
# ...

# %% [markdown]
# ### View global of dataset through graphics

# %%
pairplot = sns.pairplot(data=df,hue='crop_yield', palette='deep')
plt.show()

# %%
df.corr()
# Out:
#                     rainfall_mm  soil_quality_index  farm_size_hectares  \
# rainfall_mm            1.000000           -0.022198            0.001127
# soil_quality_index    -0.022198            1.000000            0.005829
# farm_size_hectares     0.001127            0.005829            1.000000
# sunlight_hours        -0.005250            0.002187           -0.010054
# fertilizer_kg         -0.029317            0.007254           -0.008032
# crop_yield             0.086339            0.043990            0.989201
#
#                     sunlight_hours  fertilizer_kg  crop_yield
# rainfall_mm              -0.005250      -0.029317    0.086339
# soil_quality_index        0.002187       0.007254    0.043990
# farm_size_hectares       -0.010054      -0.008032    0.989201
# sunlight_hours            1.000000       0.016289   -0.006792
# fertilizer_kg             0.016289       1.000000    0.102023
# crop_yield               -0.006792       0.102023    1.000000

# %%
sns.lineplot(data=df, x='soil_quality_index', y='sunlight_hours')
sns.scatterplot(data=df, x='soil_quality_index', y='sunlight_hours', hue='crop_yield')
plt.show()

# %%
len(df['crop_yield'].unique())
# Out:
# 546

# %%
df['crop_yield'].sort_values(ascending=False).head()
# Out:
# 2288    628
# 1363    623
# 1676    617
# 1794    613
# 1681    611
# Name: crop_yield, dtype: int64
